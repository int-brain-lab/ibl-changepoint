# %% [markdown]
# This script loads behavioral mice data (from `biasedChoiceWorld` protocol and, separately, the last three sessions of training) only from mice that pass a given (stricter) training criterion. For the `biasedChoiceWorld` protocol, only sessions achieving the `trained_1b` and `ready4ephysrig` training status are collected.
# The data are slightly reformatted and saved as `.csv` files.

# %%
import datajoint as dj
dj.config['database.host'] = 'datajoint.internationalbrainlab.org'

from ibl_pipeline import subject, acquisition, action, behavior, reference, data
from ibl_pipeline.analyses.behavior import PsychResults, SessionTrainingStatus
from ibl_pipeline.utils import psychofit as psy
from ibl_pipeline.analyses import behavior as behavior_analysis

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Connecting lacerbi@datajoint.internationalbrainlab.org:3306

# %%
import os
myPath = r"C:\Users\Luigi\Documents\GitHub\ibl-changepoint\data" # Write here your data path
os.chdir(myPath)

# %%
# Get list of mice that satisfy given training criteria (stringent trained_1b)
# Check query from behavioral paper: 
# https://github.com/int-brain-lab/paper-behavior/blob/master/paper_behavior_functions.py

subj_query = (subject.Subject * subject.SubjectLab * reference.Lab * subject.SubjectProject
                  & 'subject_project = "ibl_neuropixel_brainwide_01"').aggr(
                          (acquisition.Session * behavior_analysis.SessionTrainingStatus())
#                          & 'training_status="trained_1a" OR training_status="trained_1b"',
#                          & 'training_status="trained_1b" OR training_status="ready4ephysrig"',
                          & 'training_status="trained_1b"',
                          'subject_nickname', 'sex', 'subject_birth_date', 'institution',
                          date_trained='min(date(session_start_time))')

subjects = (subj_query & 'date_trained < "2019-09-30"')

mice_names = sorted(subjects.fetch('subject_nickname'))

print(mice_names)
# Out:
# ['CSHL_002', 'CSHL_003', 'CSHL_005', 'CSHL_008', 'CSHL_010', 'CSHL_014', 'CSHL_015', 'CSH_ZAD_001', 'CSH_ZAD_003', 'CSH_ZAD_004', 'CSH_ZAD_006', 'CSH_ZAD_007', 'CSH_ZAD_010', 'DY_001', 'DY_006', 'DY_007', 'IBL-T1', 'IBL-T2', 'IBL-T4', 'IBL_001', 'IBL_002', 'KS002', 'KS003', 'KS004', 'KS005', 'KS014', 'KS015', 'KS016', 'KS017', 'KS019', 'NYU-01', 'NYU-02', 'NYU-06', 'SWC_009', 'SWC_013', 'SWC_014', 'ZM_1084', 'ZM_1085', 'ZM_1086', 'ZM_1087', 'ZM_1091', 'ZM_1092', 'ZM_1097', 'ZM_1098', 'ZM_1367', 'ZM_1371', 'ZM_1372', 'ZM_1743', 'ZM_1745', 'ZM_1746', 'ZM_1747', 'ibl_witten_03', 'ibl_witten_04', 'ibl_witten_05', 'ibl_witten_06', 'ibl_witten_12', 'ibl_witten_14', 'ibl_witten_15', 'ibl_witten_16']

# %%
sess_train  = ((acquisition.Session * behavior_analysis.SessionTrainingStatus) & 
               'task_protocol LIKE "%training%"' & 'session_start_time < "2019-09-30"')
sess_stable = ((acquisition.Session * behavior_analysis.SessionTrainingStatus) & 
               'task_protocol LIKE "%biased%"' & 'session_start_time < "2019-09-30"' & 
               ('training_status="trained_1b" OR training_status="ready4ephysrig"'))
              
stable_mice_names = list()

# Perform at least this number of sessions
MinSessionNumber = 4

def get_mouse_data(df):
    position_deg = 35.    # Stimuli appear at +/- 35 degrees

    # Create new dataframe
    datamat = pd.DataFrame()
    datamat['trial_num'] = df['trial_id']
    datamat['session_num'] = np.cumsum(df['trial_id'] == 1)
    datamat['stim_probability_left'] = df['trial_stim_prob_left']
    signed_contrast = df['trial_stim_contrast_right'] - df['trial_stim_contrast_left']
    datamat['contrast'] = np.abs(signed_contrast)
    datamat['position'] = np.sign(signed_contrast)*position_deg
    datamat['response_choice'] = df['trial_response_choice']
    datamat.loc[df['trial_response_choice'] == 'CCW','response_choice'] = 1
    datamat.loc[df['trial_response_choice'] == 'CW','response_choice'] = -1
    datamat.loc[df['trial_response_choice'] == 'No Go','response_choice'] = 0
    datamat['trial_correct'] = np.double(df['trial_feedback_type']==1)
    datamat['reaction_time'] = df['trial_response_time'] - df['trial_stim_on_time'] # double-check

    # Since some trials have zero contrast, need to compute the alleged position separately
    datamat.loc[(datamat['trial_correct'] == 1) & (signed_contrast == 0),'position'] = \
        datamat.loc[(datamat['trial_correct'] == 1) & (signed_contrast == 0),'response_choice']*position_deg
    datamat.loc[(datamat['trial_correct'] == 0) & (signed_contrast == 0),'position'] = \
        datamat.loc[(datamat['trial_correct'] == 0) & (signed_contrast == 0),'response_choice']*(-position_deg)
    
    return datamat

# %%
# Loop over all mice
for mouse_nickname in mice_names:
    
    mouse_subject = {'subject_nickname': mouse_nickname}
    
    # Get mouse data for biased sessions
    behavior_stable = (behavior.TrialSet.Trial & (subject.Subject & mouse_subject)) \
        * sess_stable.proj('session_uuid','task_protocol','session_start_time','training_status') * subject.Subject.proj('subject_nickname') \
        * subject.SubjectLab.proj('lab_name')
    df = pd.DataFrame(behavior_stable.fetch(order_by='subject_nickname, session_start_time, trial_id', as_dict=True))

    if len(df) > 0:           # The mouse has performed in at least one stable session with biased blocks            
        datamat = get_mouse_data(df)

        # Take mice that have performed a minimum number of sessions
        if np.max(datamat['session_num']) >= MinSessionNumber:

            # Should add 'N' to mice names that start with numbers?

            # Save dataframe to CSV file
            filename = mouse_nickname + '.csv'
            datamat.to_csv(filename,index=False)
            stable_mice_names.append(mouse_nickname)
            
            # Get mouse last sessions of training data
            behavior_train = (behavior.TrialSet.Trial & (subject.Subject & mouse_subject)) \
                * sess_train.proj('session_uuid','task_protocol','session_start_time') * subject.Subject.proj('subject_nickname') \
                * subject.SubjectLab.proj('lab_name')
            df_train = pd.DataFrame(behavior_train.fetch(order_by='subject_nickname, session_start_time, trial_id', as_dict=True))

            datamat_train = get_mouse_data(df_train)
            Nlast = np.max(datamat_train['session_num']) - 3
            datamat_final = datamat_train[datamat_train['session_num'] > Nlast]

            # Save final training dataframe to CSV file
            filename = mouse_nickname + '_endtrain.csv'
            datamat_final.to_csv(filename,index=False)
            

print(stable_mice_names)

# %%
ss = (((acquisition.Session * behavior_analysis.SessionTrainingStatus) & 
               'task_protocol LIKE "%biased%"' & 'session_start_time < "2019-09-30"' & 
               ('training_status="trained_1b" OR training_status="ready4ephysrig"')) * subject.Subject) & ('subject_nickname = "ibl_witten_07"')

# %%
ss
# Out:
# *subject_uuid  *session_start session_uuid   session_number session_end_ti session_lab    session_locati task_protocol  session_type   session_narrat session_ts     training_statu subject_nickna sex     subject_birth_ ear_mark     subject_line   subject_source protocol_numbe subject_descri subject_ts
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +-----+ +------------+ +----------+ +------------+ +------------+ +------------+ +------------+ +------------+
# 02120449-9b19- 2019-07-18 12: 8a0cf27e-0044- 1              2019-07-18 13: wittenlab      _iblrig_witten _iblrig_tasks_ Experiment     None           2019-08-06 21: ready4ephysrig ibl_witten_07  F       2018-11-13     None         C57BL/6J       Jax            3              None           2019-09-25 01:
# 02120449-9b19- 2019-07-19 13: 180a2e18-c4fe- 1              2019-07-19 14: wittenlab      _iblrig_witten _iblrig_tasks_ Experiment     None           2019-08-06 21: ready4ephysrig ibl_witten_07  F       2018-11-13     None         C57BL/6J       Jax            3              None           2019-09-25 01:
# 02120449-9b19- 2019-07-22 16: 84a43b9d-43d4- 1              2019-07-22 18: wittenlab      _iblrig_witten _iblrig_tasks_ Experiment     None           2019-08-06 21: ready4ephysrig ibl_witten_07  F       2018-11-13     None         C57BL/6J       Jax            3              None           2019-09-25 01:
# 02120449-9b19- 2019-07-23 11: 539f6608-9ff5- 1              2019-07-23 13: wittenlab      _iblrig_witten _iblrig_tasks_ Experiment     None           2019-08-06 21: ready4ephysrig ibl_witten_07  F       2018-11-13     None         C57BL/6J       Jax            3              None           2019-09-25 01:
# 02120449-9b19- 2019-07-24 12: ed763960-490d- 1              2019-07-24 13: wittenlab      _iblrig_witten _iblrig_tasks_ Experiment     None           2019-08-06 21: ready4ephysrig ibl_witten_07  F       2018-11-13     None         C57BL/6J       Jax            3              None           2019-09-25 01:
# 02120449-9b19- 2019-07-25 11: fd8f339d-55d8- 1              2019-07-25 13: wittenlab      _iblrig_witten _iblrig_tasks_ Experiment     None           2019-08-06 21: ready4ephysrig ibl_witten_07  F       2018-11-13     None         C57BL/6J       Jax            3              None           2019-09-25 01:
# 02120449-9b19- 2019-07-26 11: 0e8fe973-05d0- 1              2019-07-26 12: wittenlab      _iblrig_witten _iblrig_tasks_ Experiment     None           2019-08-06 21: ready4ephysrig ibl_witten_07  F       2018-11-13     None         C57BL/6J       Jax            3              None           2019-09-25 01:
# 02120449-9b19- 2019-07-29 12: 61a88005-d3ff- 2              2019-07-29 14: wittenlab      _iblrig_witten _iblrig_tasks_ Experiment     None           2019-08-06 21: ready4ephysrig ibl_witten_07  F       2018-11-13     None         C57BL/6J       Jax            3              None           2019-09-25 01:
# 02120449-9b19- 2019-07-30 10: 411f83e6-7251- 1              2019-07-30 11: wittenlab      _iblrig_witten _iblrig_tasks_ Experiment     None           2019-08-06 21: ready4ephysrig ibl_witten_07  F       2018-11-13     None         C57BL/6J       Jax            3              None           2019-09-25 01:
# 02120449-9b19- 2019-07-31 10: 34273b65-92d6- 1              2019-07-31 12: wittenlab      _iblrig_witten _iblrig_tasks_ Experiment     None           2019-08-06 21: ready4ephysrig ibl_witten_07  F       2018-11-13     None         C57BL/6J       Jax            3              None           2019-09-25 01:
# 02120449-9b19- 2019-08-01 11: 1457f2ff-0673- 1              2019-08-01 12: wittenlab      _iblrig_witten _iblrig_tasks_ Experiment     Water valve wa 2019-08-06 21: ready4ephysrig ibl_witten_07  F       2018-11-13     None         C57BL/6J       Jax            3              None           2019-09-25 01:
# 02120449-9b19- 2019-08-02 10: 6be3c374-da0b- 1              2019-08-02 12: wittenlab      _iblrig_witten _iblrig_tasks_ Experiment     None           2019-08-06 21: ready4ephysrig ibl_witten_07  F       2018-11-13     None         C57BL/6J       Jax            3              None           2019-09-25 01:
#    ...
#  (Total: 44)

# %%
# Out:
# array([(UUID('0026c82d-39e4-4c6b-acb3-303eb4b24f05'), 'IBL_32', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('00778394-c956-408d-8a6c-ca3b05a611d5'), 'KS019', 'F', datetime.date(2019, 6, 18), None, 'C57BL/6J', None, 2, None, datetime.datetime(2019, 8, 13, 17, 7, 33)),
#        (UUID('00c60db3-74c3-4ee2-9df9-2c84acf84e92'), 'ibl_witten_10', 'F', datetime.date(2018, 11, 13), 'notag', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 25)),
#        (UUID('0124f697-16ce-4f59-b87c-e53fcb3a27ac'), '6867', 'M', datetime.date(2018, 6, 25), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 25)),
#        (UUID('019a22c1-b944-4494-9e38-0e45ae6697bf'), 'SWC_022', 'M', datetime.date(2019, 6, 18), 'NA (Front HP)', 'C57BL/6J', 'Charles River', 4, 'ID: 990762', datetime.datetime(2019, 9, 25, 1, 33, 25)),
#        (UUID('02120449-9b19-4276-a434-513886c2fb19'), 'ibl_witten_07', 'F', datetime.date(2018, 11, 13), None, 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 25)),
#        (UUID('034c07c5-69b0-48c7-ab3e-e491e4dbb725'), 'IBL_25', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('034fd43f-ee35-450b-99ef-25475ce25fdc'), 'ZM_1092', 'M', datetime.date(2018, 10, 23), 'RLF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 25)),
#        (UUID('037d8473-8309-4d7a-96fb-f943be8e8df3'), 'ZM_328', 'M', datetime.date(2018, 8, 7), 'LF', 'Vglut2-Cre', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 26)),
#        (UUID('03956b1f-6836-4c5f-9dea-b57b5292b177'), '6870', 'M', datetime.date(2018, 6, 25), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 26)),
#        (UUID('04514b76-e878-40a5-b6cd-2c6a205bafb3'), 'ZM_1088', 'M', datetime.date(2018, 10, 23), 'RF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 26)),
#        (UUID('05821271-3125-48dc-855b-4165900622af'), '6814', 'M', datetime.date(2018, 6, 17), None, 'Dat-Cre', 'CCU - Margarida colonies', 3, 'When removed the head plate when the mouse was sached, the skull was mushy', datetime.datetime(2019, 9, 25, 1, 33, 26)),
#        (UUID('05e97eea-64e2-4e52-a78a-5b78875b4fa3'), 'KS004', 'F', datetime.date(2018, 12, 4), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('05ff9c40-a1c6-479c-9655-3125b41a0673'), 'lic_1', 'M', datetime.date(2019, 12, 28), 'NA', 'Dat-Cre', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('062cf8a2-96db-4766-9ff3-eb52bf56fff8'), '6513', 'M', datetime.date(2018, 4, 20), None, 'Dat-Cre', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 26)),
#        (UUID('063bc242-80a7-4356-abfe-bc9d475fa8e1'), 'IBL_16', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('069f108c-c144-40c1-953d-2502950de79d'), 'CSK-scan-007', 'M', datetime.date(2019, 6, 13), None, 'VGAT-ChR2', 'CSHL-Harris', 3, 'clear skull cap for inhibition scan in IBL task', datetime.datetime(2019, 8, 30, 4, 24, 54)),
#        (UUID('069f70bb-9756-441b-aa69-76b4155547e4'), 'ZM_202', 'F', datetime.date(2018, 7, 22), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 26)),
#        (UUID('07197d1f-0074-4c1d-8b75-18ba81dcd12d'), 'KS001_optoproject', 'M', datetime.date(2018, 10, 23), 'ML', 'Ai32cg x PVCre', 'Cruciform BSU', 3, None, datetime.datetime(2019, 8, 14, 12, 19, 13)),
#        (UUID('077d4b11-c784-4cb9-983c-5a596815434f'), 'ZM_1735', 'F', datetime.date(2019, 2, 27), None, 'C57BL/6J', 'CCU - Vivarium colonies', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('07befa52-9512-4b7b-a744-c4ffd9ee6b66'), '6873', 'F', datetime.date(2018, 6, 25), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 26)),
#        (UUID('088b6898-0a86-435e-b91f-eab829a846f6'), 'SWC_005', 'M', datetime.date(2019, 1, 19), 'NA (Rear HP)', 'C57BL/6J', 'Charles River', 4, 'ID: 919175', datetime.datetime(2019, 9, 25, 1, 33, 26)),
#        (UUID('0932d382-3fd4-4688-88d1-a0156cadd488'), 'CSH_ZAD_007', 'M', datetime.date(2019, 5, 6), 'L', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('0936a724-2151-446f-98b2-92c3e9dd36dc'), 'CSHL_007', 'F', datetime.date(2018, 11, 27), 'L', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('09629112-d258-4f00-86f0-e9374dcb7cb3'), 'ZM_1887', 'F', datetime.date(2019, 3, 4), None, 'C57BL/6J', 'Jax', 3, 'Black tail tip', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('09857e7a-ce23-4abf-acb7-cbf1988a6f69'), 'CSK-IBL-005', 'M', datetime.date(2018, 12, 11), 'left left', 'C57BL/6J', 'Jax', 3, 'visual cortex lesion after training', datetime.datetime(2019, 9, 25, 1, 33, 26)),
#        (UUID('09da30a5-53cd-4f69-85d9-1accb3fa523b'), 'CSHL028', 'M', datetime.date(2019, 2, 19), 'RL', 'C57BL/6J', None, 1, None, datetime.datetime(2019, 9, 25, 1, 33, 26)),
#        (UUID('0b564fa1-e9f9-4246-9892-bb3a47eb61f7'), 'example_CSHL2', 'U', None, None, None, None, 1, 'example mouse, no real animal', datetime.datetime(2019, 8, 6, 20, 32, 56)),
#        (UUID('0d219ef3-6282-4602-b99f-a40d06d99bb2'), 'SWC_002', 'F', datetime.date(2019, 1, 19), 'L (Front HP)', 'C57BL/6J', 'Charles River', 4, 'ID: 919178', datetime.datetime(2019, 9, 25, 1, 33, 26)),
#        (UUID('0d3d977a-0263-46a9-aaa1-0139f473e811'), 'IBL_40', 'M', datetime.date(2018, 5, 24), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('0ed938a2-dd07-4742-b282-34674f5474da'), 'test_mouse1', 'F', datetime.date(2018, 11, 13), None, 'Vip-IRES-Cre', 'Jax', 1, None, datetime.datetime(2019, 8, 6, 20, 32, 56)),
#        (UUID('0fbb1324-1ac7-445a-8831-8fc2225338ca'), 'CSH_ZAD_010', 'M', datetime.date(2019, 5, 6), 'none', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('10a1fd99-5d9d-4a64-827b-f198627e330f'), 'CSK-scan-006', 'M', datetime.date(2019, 6, 13), 'R', 'VGAT-ChR2', 'CSHL-Harris', 3, 'clear skull prep for inhibition scanning in IBL task', datetime.datetime(2019, 8, 29, 4, 24, 21)),
#        (UUID('10fd3170-6c52-4cb6-986f-aa73704277c0'), 'CSHL_015', 'F', datetime.date(2019, 2, 19), None, 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 27)),
#        (UUID('11a7eff3-48db-42e3-9727-344270357e24'), 'ZM_1742', 'F', datetime.date(2019, 3, 4), None, 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('1208c089-8b8e-4a87-98f0-05a68fb18370'), 'IBL_13', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('122205e8-0a31-41ce-9632-30e7857a959d'), 'IBL_35', 'M', datetime.date(2018, 5, 24), None, None, 'Charles River', 1, 'Culled 1/22/19 due to growth on headbar', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('1229561e-850d-4cd5-bfcb-3d99a87c6de1'), 'IBL_2', 'M', datetime.date(2018, 4, 2), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('13bb1517-5bc6-47fa-b2ce-a9194d338efb'), 'KS007', 'M', datetime.date(2018, 12, 10), None, 'C57BL/6J', None, 3, 'implantation headbar (posterior)+ 3d printed guide; cut back muscles; recovery after 30 min;', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('13e59361-a2e8-4e2d-8636-ae0961fd941c'), 'ZM_1093', 'M', datetime.date(2018, 10, 23), None, 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 27)),
#        (UUID('146f0531-6eb1-4af2-b179-f7fa5a7289e1'), 'IBL_7', 'M', datetime.date(2018, 4, 3), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('155b6df6-02eb-4153-a997-c8dbe283a0dc'), 'CSK-les-008', 'M', datetime.date(2019, 2, 5), 'left left', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('16934e63-87c4-485f-b1ef-5f3e82e0a2ff'), 'ZM_1889', 'M', datetime.date(2019, 3, 4), None, 'C57BL/6J', None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('16f6e3f1-7bcd-45d7-9353-c0c31ae13218'), 'LTC05', 'F', datetime.date(2019, 6, 26), 'L', None, None, 1, None, datetime.datetime(2019, 8, 20, 4, 20, 52)),
#        (UUID('18a54f60-534b-4ed5-8bda-b434079b8ab8'), 'KS014', 'M', datetime.date(2019, 6, 18), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('18aba430-9f7d-4888-ae53-4efbc86bf152'), 'CSK-les-011', 'M', datetime.date(2018, 11, 26), 'L', 'EMX-IRES-Cre', 'CSHL-Harris', 3, 'AAV-dtr injected mouse to check injection protocol for targeting visual cortex', datetime.datetime(2019, 9, 25, 1, 33, 27)),
#        (UUID('19614813-ce3b-4b7d-bf52-562d2a304754'), 'CSK-IBL-004', 'M', datetime.date(2018, 12, 11), 'right right', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('19cf7867-e2d2-4a12-93be-9371fe1a293c'), 'CSHL_010', 'F', datetime.date(2018, 11, 27), 'left, left', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('1a08c0fa-5646-4b68-9703-0dd6b805c69d'), 'SWC_007', 'M', datetime.date(2019, 3, 27), 'NA (Rear HP)', 'C57BL/6J', 'Charles River', 4, None, datetime.datetime(2019, 9, 25, 1, 33, 27)),
#        (UUID('1a8fa9b4-399b-4175-8c32-e552aaa2541b'), 'ZM_1373', 'F', datetime.date(2018, 12, 31), None, 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 27)),
#        (UUID('1c420533-3f46-43dd-98bf-4a4c30093f11'), 'CSK-les-009', 'M', datetime.date(2019, 2, 26), 'R', 'EMX-IRES-Cre', 'CSHL-Harris', 3, 'mouse with AAV-dtr injected in visual cortex bilaterally', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('1d785ee9-76b0-42b2-9cd2-3982ccd4bf88'), 'ZM_1747', 'M', datetime.date(2019, 2, 24), None, 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('1deb9263-97d5-433b-90ab-0c10512bb706'), 'ZM_206', 'M', datetime.date(2018, 7, 23), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 27)),
#        (UUID('1f413ca0-2584-4307-8c5b-918bc17771f7'), 'IBL_41', 'M', datetime.date(2018, 5, 24), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('1fce4668-e99f-4e50-9f75-961842781a23'), 'IBL_36', 'M', datetime.date(2018, 5, 24), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('204d40b0-7ea8-49b3-835c-05b47ec8801b'), 'ZM_1746', 'M', datetime.date(2019, 2, 24), 'RF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('20712965-a9c8-4112-a4a8-166b31cf1bca'), 'CSK-scan-002', 'M', datetime.date(2019, 4, 9), 'RRL', 'VGAT-ChR2', 'Jax', 3, 'VGat-ChR2 mouse with cleared skull preparation and headbar for scanning inactivation in IBL task', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('217d49ae-ada9-48be-a77e-9704c9e57855'), 'NYU-01', 'M', datetime.date(2018, 12, 18), '1', None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('21e1df44-3aaf-44bc-bb50-60793591a260'), '6869', 'M', datetime.date(2018, 6, 25), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 28)),
#        (UUID('2498cb76-8d25-4a84-84ca-0c413028e0c3'), '6872', 'F', datetime.date(2018, 6, 25), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 28)),
#        (UUID('24ccb0ca-c7cb-4cf0-844c-bd426af9bc56'), 'IBL_17', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('274bb80c-2acc-470a-bfb4-24d38a1b3d06'), 'ibl_witten_06', 'M', datetime.date(2018, 11, 6), 'RL', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 28)),
#        (UUID('278bf922-073e-4ef4-90b5-ccf4e25e08fe'), 'IBL_26', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('27c8be70-bea2-4007-91c1-42df0de0ff77'), '4576', 'M', datetime.date(2017, 4, 11), None, 'Vglut2-ChR2', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 28)),
#        (UUID('27d08c9d-6013-42d8-bab5-1e788f230b2e'), 'SWC_001', 'F', datetime.date(2019, 1, 19), 'R (Front HP)', 'C57BL/6J', 'Charles River', 4, 'ID: 919179', datetime.datetime(2019, 9, 25, 1, 33, 28)),
#        (UUID('29096382-c115-4a27-8a35-e379c36f451a'), '4580', 'F', datetime.date(2017, 4, 11), None, 'Vglut2-ChR2', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 28)),
#        (UUID('29a27868-db95-4c6d-a1cc-7c9226f032a3'), 'CSHL_019', 'M', datetime.date(2018, 10, 10), 'RR', 'C57BL/6J', 'CSHL - Woodbury', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 28)),
#        (UUID('2a8a62f8-7808-4b41-a259-0aca3cc8b7c8'), 'ZM_2102', 'U', datetime.date(2019, 6, 10), 'RF', None, None, 1, 'Blinded experiment.', datetime.datetime(2019, 9, 11, 4, 29, 18)),
#        (UUID('2a99bc35-a868-498c-986b-33bb140ecab3'), 'TetO_0055_Breeding', 'U', None, None, None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('2bc03c63-c266-43bf-905e-5aa6ea71a294'), 'ibl_witten_11', 'F', datetime.date(2019, 3, 19), 'NA', 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('2cbfb932-ed7e-47b1-893f-100f9329c21c'), 'KS003', 'M', datetime.date(2018, 10, 30), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('2ce41c85-6e8f-4b0b-b2a6-4e172c0584f7'), 'IBL_43', 'M', datetime.date(2018, 7, 16), None, None, 'Charles River', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('2d4291f4-a426-4fc4-9ef1-8d13bfd450f4'), 'CSP003', 'M', datetime.date(2019, 2, 6), 'CSP3 on headbar', None, None, 1, None, datetime.datetime(2019, 8, 13, 17, 7, 33)),
#        (UUID('2f1b7046-9c58-4076-a7c5-7c386293dc89'), 'DY_006', 'M', datetime.date(2019, 3, 20), 'none', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 28)),
#        (UUID('2fda7778-75f3-439b-9702-9a69b6f084d9'), 'VAR-IBL-002', 'F', datetime.date(2019, 1, 11), 'Left', None, 'Charles River', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('33c0db12-134b-4925-a8b4-ea2dac4e7f0e'), '5857', 'M', datetime.date(2017, 12, 17), None, 'Dat-Cre', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 28)),
#        (UUID('33eeea5f-f287-4234-85bd-512900d63c1f'), 'SWC_017', 'F', datetime.date(2019, 5, 7), 'L (Mid HP)', 'C57BL/6J', 'Charles River', 1, 'ID: 968399', datetime.datetime(2019, 9, 25, 1, 33, 28)),
#        (UUID('342f4745-7606-4506-b81d-c7e27ed78c44'), 'ZM_342', 'F', datetime.date(2018, 8, 8), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 28)),
#        (UUID('34d5b181-e7c8-4022-aab7-fce1e2640b57'), 'IBL_45', 'M', datetime.date(2018, 7, 16), None, None, 'Charles River', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('34ff50d4-42cf-41f7-8c38-ab631ca84d74'), 'IBL-T4', 'F', datetime.date(2018, 11, 27), '4', None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('354b105f-53f7-41c7-98aa-46f731aa9e29'), 'ZM_346', 'F', datetime.date(2018, 8, 8), 'RLF', 'Thy1-GCaMP6s', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 29)),
#        (UUID('354e6122-de4a-4945-bafd-d46df65768f6'), 'KS016', 'M', datetime.date(2019, 6, 18), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('37c8f897-cbcc-4743-bad6-764ccbbfb190'), 'IBL_14', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('37f8e3ef-3766-4d46-bda9-65918e919d27'), 'CSHL032', 'M', datetime.date(2019, 5, 24), 'L', 'C57BL/6J', 'CSHL - Woodbury', 3, None, datetime.datetime(2019, 9, 4, 4, 27, 55)),
#        (UUID('386215c9-8883-4938-be19-5978b36ce450'), 'VAR-IBL-001', 'F', datetime.date(2019, 1, 11), 'Right', None, None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('3899bc0a-d7b5-4914-a76f-a4f4fdd99f98'), 'ZM_1089', 'M', datetime.date(2018, 10, 23), 'RLF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 29)),
#        (UUID('38ac0165-7418-4514-9d2d-ef40d4384fa4'), 'SWC_019', 'F', datetime.date(2019, 7, 9), 'NA (Front HP)', 'C57BL/6J', 'Charles River', 4, 'ID: 980129', datetime.datetime(2019, 9, 25, 1, 33, 29)),
#        (UUID('38d4f937-f928-4c39-bc5e-7379d680cb1a'), '6723', 'M', datetime.date(2018, 6, 3), None, 'Dat-Cre', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 29)),
#        (UUID('39b5e079-a67f-4b70-99d9-e11f3fbc7cc8'), 'CSK-scan-003', 'M', datetime.date(2019, 4, 9), 'RR', 'VGAT-ChR2', 'Jax', 3, 'VGat-ChR2 mouse with cleared skull preparation and headbar for scanning inactivation in IBL task', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('3b6b41b6-68bb-4a9a-bfeb-5f8cf97a1c2a'), 'ZM_1745', 'M', datetime.date(2019, 2, 24), None, 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('3cc9e62f-5a3d-43ab-9ed6-66dcc6d3a3be'), 'ZM_208', 'M', datetime.date(2018, 7, 23), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 29)),
#        (UUID('3d9f702a-3e39-497c-ac78-49b43527ac0d'), 'ibl_witten_09', 'F', datetime.date(2018, 11, 13), 'LR', None, 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('3e97e1d3-2a0f-44e5-b63f-36196d78457a'), 'IBL_34', 'M', datetime.date(2018, 5, 24), None, None, 'Charles River', 1, 'Culled 16/09/2019 due to growth on headbar', datetime.datetime(2019, 9, 25, 1, 33, 29)),
#        (UUID('3eee82bf-8ccf-42ac-9e26-472caed5f265'), 'NYU-02', 'M', datetime.date(2018, 12, 18), '2', None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('3eef59f3-55af-4b09-ba38-6408482a7e88'), 'ZM_1896', 'U', datetime.date(2019, 6, 10), 'RF', None, None, 1, 'Blinded experiment.', datetime.datetime(2019, 9, 11, 4, 29, 18)),
#        (UUID('3f854f88-7879-4368-9e0d-41edea3bfab9'), 'IBL_11', 'M', datetime.date(2018, 4, 2), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('3fa7fdbe-92b4-4836-b6e7-4ee1c4ba2d2a'), 'CSK-les-006', 'M', datetime.date(2019, 2, 5), 'left', 'C57BL/6J', 'Jax', 3, 'mouse with bilateral visual cortex aspirations, aspirations done before training. used to pilot learning of IBL task in the absence of vis ctx', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('3fd39054-7d08-4e5e-b766-b349885c94b1'), 'ZM_1376', 'F', datetime.date(2018, 12, 31), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('406b8a6e-89fd-44da-961b-9335b12f3bfa'), 'SWC_016', 'F', datetime.date(2019, 5, 7), 'LR (Front HP)', 'C57BL/6J', 'Charles River', 1, 'ID: 968401', datetime.datetime(2019, 9, 25, 1, 33, 29)),
#        (UUID('4372e7ab-0978-4aff-81eb-e922e8b69920'), 'test_human', 'U', datetime.date(2019, 7, 18), None, None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('43b91da7-0be5-493a-bec5-ebd8d624a573'), 'ZM_209', 'M', datetime.date(2018, 7, 23), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 29)),
#        (UUID('43e29661-4f4e-4bee-8f7f-4e7853e53356'), 'ZM_2108', 'U', datetime.date(2019, 6, 10), 'LB', None, None, 1, 'Blinded experiment.', datetime.datetime(2019, 9, 11, 4, 29, 18)),
#        (UUID('45908f39-0e44-4c6d-aeb9-6b1de36f9208'), 'dop_3', 'M', datetime.date(2018, 8, 15), None, 'Dat-Cre', None, 3, None, datetime.datetime(2019, 9, 25, 1, 33, 29)),
#        (UUID('45c4db5f-9bcd-47e2-acf2-8b7e882848fd'), 'LTC01', 'F', datetime.date(2019, 3, 17), '1', None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('45e9d4c4-5ab5-4140-ba29-853d57612333'), 'KS009', 'M', datetime.date(2018, 12, 10), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('46dd5793-4e56-460e-92d6-03da4f8f6789'), '5822', 'F', datetime.date(2017, 12, 10), None, 'ChR2', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 30)),
#        (UUID('475acc5f-64f7-4f28-9722-5f60ce553f91'), 'DY_007', 'M', datetime.date(2019, 3, 20), 'none', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 30)),
#        (UUID('47d55843-2e2c-4ade-ad26-98d8f93cd7af'), 'dop_4', 'M', datetime.date(2018, 12, 28), '66', 'Dat-Cre', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('48952b61-705f-415c-b749-7bc75bd393f5'), 'LTC07', 'M', datetime.date(2019, 6, 26), 'RL', None, None, 1, None, datetime.datetime(2019, 8, 20, 4, 20, 52)),
#        (UUID('48eaad5d-a67d-42ed-9995-7084aa441dc7'), 'KS008', 'M', datetime.date(2018, 12, 10), None, 'C57BL/6J', None, 3, 'headbar implantation (posterior); without cutting back muscles; recovered after 20 min.', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('4a5fa869-d57e-4b67-8a6a-775f4f239d7b'), 'CSHL022', 'F', datetime.date(2019, 2, 19), 'L', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 20, 4, 20, 52)),
#        (UUID('4ba96259-4afe-42fa-89b6-f2f8d361bf44'), 'ZM_1095', 'M', datetime.date(2018, 10, 23), 'RLF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 30)),
#        (UUID('4c662aec-bf19-447b-b101-640fd761d422'), 'CSHL026', 'F', datetime.date(2019, 2, 19), 'R', 'C57BL/6J', 'Jax', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 30)),
#        (UUID('4c9577b3-bdd5-4a15-b15b-5bc24a4439d3'), 'CSHL_002', 'M', datetime.date(2018, 11, 20), 'left ear', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('4db0b36d-9b85-4cae-8d93-a68998c581fc'), 'SWC_013', 'M', datetime.date(2019, 6, 4), 'NA (Front HP)', 'C57BL/6J', 'Charles River', 4, 'ID: 980125', datetime.datetime(2019, 9, 25, 1, 33, 30)),
#        (UUID('4db14483-21ff-4102-a71f-07434e8a1396'), 'KS021', 'M', datetime.date(2019, 6, 25), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 9, 20, 4, 28, 14)),
#        (UUID('4dc08527-efd9-41c7-b907-f610f3ad41ae'), 'CSH_ZAD_004', 'F', datetime.date(2019, 4, 16), 'RR', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('4e4b8689-cfc7-40b1-986a-b8d642920c98'), 'CSP004', 'M', datetime.date(2019, 7, 26), None, None, None, 1, None, datetime.datetime(2019, 9, 17, 4, 26, 51)),
#        (UUID('4eb8afda-a4d9-4314-8956-cdf773223fe5'), 'ZM_1897', 'U', datetime.date(2019, 6, 10), 'LF', None, None, 1, 'Blinded experiment.', datetime.datetime(2019, 9, 11, 4, 29, 18)),
#        (UUID('4f091667-90b9-4469-88f4-542c1ec07891'), 'CSHL_008', 'F', datetime.date(2018, 11, 27), 'left right', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('4f67d7f3-c31c-449b-a5b3-5533d9fe6cd6'), 'CSHL_017', 'M', datetime.date(2019, 12, 4), 'R', None, None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('4f8b92b1-ae52-4843-8605-f1c55b96833b'), 'ZM_1219', 'M', datetime.date(2019, 1, 4), 'LF', 'VGAT-ChR2', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 30)),
#        (UUID('503ed889-119a-4d91-8a39-4f52e64df25e'), 'CSHL_surgery_test1', 'M', datetime.date(2019, 1, 10), None, None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('50883573-cf52-409f-907a-3920ed1fe479'), 'IBL_47', 'M', datetime.date(2018, 7, 16), None, None, 'Charles River', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('51a449ee-b409-4cc8-9db9-2bcbbb8f1fc1'), 'KS012', 'F', datetime.date(2019, 2, 5), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('5240e410-0881-46d6-a27d-eeeb90afadeb'), 'SWC_004', 'M', datetime.date(2019, 1, 19), 'L (Front HP)', 'C57BL/6J', 'Charles River', 4, 'ID: 919174', datetime.datetime(2019, 9, 25, 1, 33, 30)),
#        (UUID('52a800fc-cbbc-45e9-97b1-ad6f6166e9af'), 'IBL_1', 'M', datetime.date(2018, 4, 2), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('52c51feb-027a-442d-9fc9-f3e361ed9651'), '5820', 'F', datetime.date(2017, 12, 10), None, 'ChR2', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 31)),
#        (UUID('535ae292-7006-44eb-9ee5-4b0838953915'), 'CSHL_009', 'F', datetime.date(2018, 11, 27), 'right, right', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('54dfc265-8670-4178-abe2-d3ebb21c1b64'), 'LTC08', 'M', datetime.date(2019, 6, 26), 'R', None, None, 1, None, datetime.datetime(2019, 8, 20, 4, 20, 52)),
#        (UUID('54edfc98-ce84-471c-94a3-c748552fbc22'), 'ibl_witten_03', 'M', datetime.date(2018, 7, 17), None, None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('55381f61-4e47-4baa-beb9-70068c0ad62c'), 'IBL_46', 'M', datetime.date(2018, 7, 16), None, None, 'Charles River', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('55e0751a-571e-47a8-bc63-cc44c859639b'), '6592', 'F', datetime.date(2018, 5, 2), None, 'Thy1-GCaMP6s', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 31)),
#        (UUID('55eb0c59-c39d-43f7-bdc3-35de0c25f7c6'), 'MW001', 'M', datetime.date(2018, 7, 17), 'TR', 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('562b327c-fd1d-4554-b608-c7de08c5849c'), 'SWC_008', 'F', datetime.date(2019, 3, 27), 'LR (Front HP)', 'C57BL/6J', 'Charles River', 1, 'ID: 945775', datetime.datetime(2019, 9, 25, 1, 33, 31)),
#        (UUID('5632ea54-93c8-4da3-87b6-4d0f5df1e409'), '6722', 'M', datetime.date(2018, 6, 3), None, 'Dat-Cre', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 31)),
#        (UUID('565ce5bf-e66e-4170-bde6-7f393428f22e'), '6594', 'F', datetime.date(2018, 5, 2), None, 'Thy1-GCaMP6s', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 31)),
#        (UUID('56a0f31c-96b1-432e-b209-dc7b71f0f61a'), 'CSHL_018', 'M', datetime.date(2018, 10, 10), 'LR', 'C57BL/6J', 'CSHL - Woodbury', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('56b81bb0-fffb-4875-9cd6-29465782fb0e'), 'IBL_24', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('5848e7f4-447d-42eb-9676-c914740df807'), 'CSHL_006', 'F', datetime.date(2018, 11, 27), 'R', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('5b2518f5-e579-4d4f-ac18-41fdfdc5e409'), 'SWC_006', 'M', datetime.date(2019, 3, 27), 'NA (Mid HP)', 'C57BL/6J', 'Charles River', 4, 'ID: 945771', datetime.datetime(2019, 9, 25, 1, 33, 31)),
#        (UUID('5ba2da46-8213-4dd1-ac4e-3dc1eafd7141'), 'KS025', 'F', datetime.date(2019, 6, 25), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 9, 26, 4, 29, 35)),
#        (UUID('5cff8b1f-288e-4725-83b6-d2f9b6c7ab45'), 'SWC_021', 'F', datetime.date(2019, 7, 9), 'L (Rear HP)', 'C57BL/6J', 'Charles River', 4, 'ID: 980127', datetime.datetime(2019, 9, 25, 1, 33, 31)),
#        (UUID('5d5f0cf1-35de-4cc5-aa52-c97d1485dfc5'), 'SH002', 'M', datetime.date(2019, 2, 6), '3', None, None, 1, None, datetime.datetime(2019, 8, 13, 17, 7, 33)),
#        (UUID('5d620809-f81f-49ce-ab00-f9b15e0a00a6'), '4579', 'F', datetime.date(2017, 4, 11), None, 'Vglut2-ChR2', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 31)),
#        (UUID('5d6f64dd-b6ca-4ab5-b412-6bf837dd7d70'), 'ZM_1744', 'F', datetime.date(2019, 3, 4), 'LF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('5da36537-a713-4f06-8512-7c01105f23db'), '6515', 'M', datetime.date(2018, 4, 20), None, 'Dat-Cre', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 31)),
#        (UUID('5df5f18e-b6a1-4e1c-8149-525952d8cdde'), 'IBL_33', 'M', datetime.date(2018, 5, 24), None, None, 'Charles River', 1, 'Culled 1/22/19 due to growth on headbar', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('5df6e2f2-cc8e-486f-a23d-219125e496fa'), 'ZM_1085', 'M', datetime.date(2018, 10, 23), 'RF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 32)),
#        (UUID('5ec8f744-0fc7-493d-b117-edd1d06b11a5'), '5635', 'F', datetime.date(2017, 11, 8), None, 'Ntsr1-Cre', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 32)),
#        (UUID('5f7d4e8d-37d7-48cf-97e5-24121285adb9'), 'ZM_1087', 'M', datetime.date(2018, 10, 23), 'RB', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 32)),
#        (UUID('60fe80b7-7506-4885-8c36-e8622025780c'), 'CSH_ZAD_001', 'F', datetime.date(2019, 4, 16), 'R', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('6318a191-5ee9-4c81-87d4-e2078572c525'), 'IBL_12', 'M', datetime.date(2018, 4, 2), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('63902e8f-d4cc-4b5d-84ae-7e862edd725f'), 'LTC03', 'F', datetime.date(2019, 2, 17), '1', None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('63b8b57b-4a14-4965-9989-39283e28a290'), 'IBL_003', 'F', datetime.date(2019, 1, 9), 'LR', None, None, 4, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('64429801-3be6-40cf-ae95-1b74e4fa189e'), 'CSP005', 'M', datetime.date(2019, 7, 26), None, None, None, 1, None, datetime.datetime(2019, 9, 17, 4, 26, 52)),
#        (UUID('64781a98-8ed4-48af-8511-477b6ac541f2'), 'dop_1', 'F', datetime.date(2018, 11, 12), 'NA', 'Dat-Cre', None, 3, None, datetime.datetime(2019, 9, 25, 1, 33, 32)),
#        (UUID('64c1bdd9-d82f-435f-ac30-fc8032c6e119'), 'ALK082', 'M', datetime.date(2018, 7, 16), 'TR', 'Pvalb-IRES-Cre', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('64ff6fea-89a5-449d-a9f4-53f4b200e7db'), 'IBL_20', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('6904fd86-a05a-4a0e-9c3d-fbaa2c4eb3aa'), 'IBL_44', 'M', datetime.date(2018, 7, 16), None, None, 'Charles River', 3, 'Culled 1/23/19 due to growth on headbar', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('6912fe58-e41f-4733-9e1b-552d1552fb0c'), 'IBL_3', 'M', datetime.date(2018, 4, 2), 'N/A', None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('691ccb90-95e6-48f0-a78b-4c10e66389cd'), 'CSK-scan-005', 'M', datetime.date(2019, 6, 13), 'RR', 'VGAT-ChR2', 'CSHL-Harris', 3, 'clear skull prep for scanning inhibition in IBL task', datetime.datetime(2019, 8, 29, 4, 24, 21)),
#        (UUID('695a9a3a-ca4c-484d-8bc5-99de95a3257a'), 'ZM_1096', 'M', datetime.date(2018, 10, 23), 'RF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 32)),
#        (UUID('6af88109-8b3d-485c-8486-f8b35d2bf061'), 'IBL_23', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('6b7d6846-2793-4f5e-b695-22461d973c4b'), 'KS011', 'F', datetime.date(2019, 2, 5), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('6ca062b9-0d05-4818-8a4e-5c6a443f23f3'), 'CSK-les-005', 'M', datetime.date(2019, 2, 5), 'Right', 'C57BL/6J', 'Jax', 3, 'mouse with bilateral visual cortex aspirations, aspirations done before training. used to pilot learning of IBL task in the absence of vis ctx', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('6d3a3635-05cd-4f5b-97c5-2c129b812a33'), 'DY_003', 'M', datetime.date(2019, 1, 1), 'none', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 32)),
#        (UUID('6d529f62-17f0-4953-a336-7c12d77ce01e'), 'C57_0077_Breeding', 'U', None, None, None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('6dcef540-d5f2-41d0-9233-55e0da87fe59'), 'ZM_1743', 'F', datetime.date(2019, 3, 4), 'RF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('6e1e46eb-a742-4385-926c-db14a8f9347f'), 'CSHL_003', 'M', datetime.date(2018, 11, 20), 'LR', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('6f43fb2b-be3e-4644-9838-56dea0013ed5'), 'ZM_1151', 'F', datetime.date(2018, 12, 27), 'RFB', 'Tbet-GCaMP6f', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 33)),
#        (UUID('6fcbebf4-30b1-4843-a65f-fdea5dca2d5f'), 'DY_004', 'M', datetime.date(2019, 1, 1), 'none', 'C57BL/6J', 'Jax', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 33)),
#        (UUID('6fff6dad-f8ad-47b4-9723-11402fa9948a'), 'ZM_2104', 'M', datetime.date(2019, 6, 13), 'white tip tail', None, 'Jax', 3, None, datetime.datetime(2019, 8, 24, 4, 35, 14)),
#        (UUID('704479d9-9375-4aaa-9e20-c304e0e8cb09'), 'ZM_200', 'M', datetime.date(2018, 7, 22), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 33)),
#        (UUID('70672c7d-cc8b-4555-be08-0795b25935b1'), 'CSHL021', 'M', datetime.date(2019, 1, 11), 'R', 'Ai14 x A2A-Cre', 'CSHL-Harris', 3, None, datetime.datetime(2019, 8, 13, 17, 7, 33)),
#        (UUID('71b6e794-e4f5-4c4b-977b-3780b3fd731f'), 'ZM_1220', 'M', datetime.date(2019, 1, 4), 'RB', 'VGAT-ChR2', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 33)),
#        (UUID('726e6b19-e9ef-4e37-a7d7-986d5bcd551c'), 'ibl_witten_15', 'M', datetime.date(2019, 4, 23), 'NA', 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('73888c99-440a-4fb2-8f6a-16bb49a04b7e'), '6512', 'M', datetime.date(2018, 4, 20), None, 'Dat-Cre', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 33)),
#        (UUID('7441cf6c-0e29-42df-b858-de9d16e0bceb'), 'ZM_2109', 'U', datetime.date(2019, 6, 10), 'RB', None, None, 1, 'Blinded experiment.', datetime.datetime(2019, 9, 11, 4, 29, 18)),
#        (UUID('75f4ced2-9fe5-44d2-b4ce-003a3977b22e'), '6726', 'F', datetime.date(2018, 6, 3), None, 'Dat-Cre', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 33)),
#        (UUID('76f99b7a-94e6-41d4-8e2d-6bdd7b1478c3'), 'ZM_335', 'M', datetime.date(2018, 8, 8), None, 'Thy1-GCaMP6s', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 33)),
#        (UUID('787af8d0-46db-4f32-bb5f-353c17d11e6c'), 'CSHL_014', 'F', datetime.date(2019, 2, 19), 'Left.Left', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 33)),
#        (UUID('79220479-3f1f-43d7-af79-c8001eaa5e3a'), 'KS017', 'F', datetime.date(2019, 6, 18), None, 'C57BL/6J', None, 2, None, datetime.datetime(2019, 8, 13, 17, 7, 33)),
#        (UUID('79dc7d34-79cd-4bd1-9d7f-cbd0fc8d8f90'), 'SWC_012', 'M', datetime.date(2019, 4, 30), 'LR (Rear HP)', 'C57BL/6J', 'Charles River', 3, 'ID: 968398', datetime.datetime(2019, 9, 25, 1, 33, 33)),
#        (UUID('7ab96ad8-a966-4437-86c6-405a20f6ce44'), 'KS013', 'F', datetime.date(2019, 2, 5), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('7afdde29-d3b7-4f2f-bc9f-d90a39dbe6f4'), 'IBL_004', 'F', datetime.date(2018, 12, 30), 'R', None, None, 4, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('7b502159-9b6b-4cd0-89c4-4947c35ee0c2'), 'CSHL031', 'M', datetime.date(2019, 2, 19), 'R', 'C57BL/6J', 'Jax', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 33)),
#        (UUID('7c751b49-55a6-4eac-9bdb-367faf2a18ee'), 'IBL_10', 'M', datetime.date(2018, 4, 2), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('7cda08b5-56d7-4b40-a9b4-07b0506a77b6'), 'ZM_1927', 'M', datetime.date(2019, 6, 20), 'RB', 'Sert-Cre', 'CCU - Margarida colonies', 1, 'Test effect of food switch on weight (Envigo 2014 > Picolab).', datetime.datetime(2019, 9, 10, 12, 30, 6)),
#        (UUID('7d334e82-1270-4346-86c2-4a8b7530946d'), 'ibl_witten_13_', 'M', datetime.date(2019, 4, 23), 'NA', 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('7dfc4f76-3ab2-4d2b-9e01-f8c76e47f770'), 'CSK-scan-008', 'M', datetime.date(2019, 6, 13), 'L', 'VGAT-ChR2', 'CSHL-Harris', 3, 'clear skull cap for inhibition scan in IBL task', datetime.datetime(2019, 9, 25, 1, 33, 33)),
#        (UUID('808d713e-2e6e-4b2e-ac84-a946a5a5fa9e'), 'KS020', 'M', datetime.date(2019, 6, 25), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 9, 20, 4, 28, 14)),
#        (UUID('80a13fa1-538e-413a-b027-7c861cd61b2b'), '438', 'M', datetime.date(2018, 6, 26), None, 'Sert-Cre', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 34)),
#        (UUID('81ddda67-4681-4b25-8e5c-dbf6cce4e105'), 'Pv_0079_Breeding', 'U', None, None, None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('82a45288-a291-43f2-a3ef-6ee77f98abd6'), 'ZM_1084', 'M', datetime.date(2018, 10, 23), 'RB', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 34)),
#        (UUID('8335b3c5-0c4b-4a69-830f-db0a2eca0d66'), 'ZM_1370', 'M', datetime.date(2018, 12, 24), 'RF', 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('83a26cbe-0720-452a-b8d6-a59f2b97288f'), 'SWC_026', 'F', datetime.date(2019, 6, 18), 'right', None, None, 1, None, datetime.datetime(2019, 9, 16, 4, 26, 26)),
#        (UUID('8417e0e4-1340-49ea-af2b-b9b0fe3803c8'), '6460', 'M', datetime.date(2018, 4, 14), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 34)),
#        (UUID('85d379ee-a5d6-4adf-a611-16603494bcbb'), 'ZM_1928', 'U', datetime.date(2019, 6, 10), 'RF', None, None, 1, 'Blinded experiment.', datetime.datetime(2019, 9, 11, 4, 29, 18)),
#        (UUID('8648a2b6-708a-48d0-9b78-d285cad6a8d5'), '4619', 'M', datetime.date(2017, 4, 24), None, 'Vglut2-Cre', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 34)),
#        (UUID('87915439-46c4-4e14-ae6d-8de65d2d1892'), 'LTM02', 'M', datetime.date(2019, 6, 26), 'L', None, None, 1, None, datetime.datetime(2019, 8, 20, 4, 20, 52)),
#        (UUID('87caaddb-2863-42f7-b7d9-804bfba9c599'), 'ibl_witten_05', 'M', datetime.date(2018, 11, 6), 'L', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 34)),
#        (UUID('885488e4-b8de-4a3e-960a-f5a851ea9954'), '5854', 'M', datetime.date(2017, 12, 17), None, 'Dat-Cre', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 34)),
#        (UUID('885bd129-55a7-4043-acdc-80bc7d96b4a5'), 'IBL_9', 'M', datetime.date(2018, 4, 2), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('8871b565-f4ea-43cd-a2b7-d7730bc22923'), '901', 'M', datetime.date(2018, 11, 8), 'LF', 'Sert-Cre', 'CCU - Margarida colonies', 3, 'Practice surgery + practice recordings.', datetime.datetime(2019, 9, 25, 1, 33, 34)),
#        (UUID('892316ab-346c-4592-a4ea-ee5e668fbdaa'), 'SWC_009', 'F', datetime.date(2019, 3, 27), 'NA (Mid HP)', 'C57BL/6J', 'Charles River', 1, 'ID: 945774', datetime.datetime(2019, 9, 25, 1, 33, 34)),
#        (UUID('8a6a484f-ca8e-4858-a6cf-672e6da9cea4'), 'CSHL029', 'M', datetime.date(2019, 2, 19), 'RR', 'C57BL/6J', None, 1, None, datetime.datetime(2019, 9, 25, 1, 33, 34)),
#        (UUID('8b79e73e-20f9-4bdc-a78e-341511d893ca'), 'ZM_1098', 'M', datetime.date(2018, 10, 23), 'LRF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 34)),
#        (UUID('8b8b13f3-f2dc-4fe9-8967-b4da51a9afa3'), 'lic3', 'M', datetime.date(2019, 3, 6), 'NA', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 34)),
#        (UUID('8b8c6499-b56b-4ac2-8394-90d057d50f94'), 'CSK-les-007', 'M', datetime.date(2019, 2, 5), 'right right', 'C57BL/6J', 'Jax', 3, 'mouse with bilateral visual cortex aspirations, aspirations done before training. used to pilot learning of IBL task in the absence of vis ctx', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('8cfed8b1-8c3c-4e81-b909-3551ac44b19a'), 'CSHL_011', 'F', datetime.date(2019, 2, 19), 'Right', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 34)),
#        (UUID('8d2f70f6-66a8-4b37-b1b1-b191c051824c'), 'IBL_30', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('8d652d52-a278-4a7d-afaf-2ec214e19b94'), 'CSH_ZAD_003', 'F', datetime.date(2019, 4, 16), 'RL', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('8d839b64-f257-4138-b797-c8eb3289610d'), 'KS010', 'M', datetime.date(2018, 12, 10), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('8dd70a83-b5d2-4c6c-86f4-e2bb33ab727d'), 'IBL_6', 'M', datetime.date(2018, 4, 2), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('8e181135-7106-43c1-9cda-d854856e6d95'), 'LEW009', 'M', datetime.date(2018, 5, 1), 'TL', 'tetO-G6s x CaMK-tTA', 'Cruciform BSU', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('8e283b43-3a44-4f30-b292-d6d975c7f935'), 'ibl_witten_02', 'M', datetime.date(2018, 7, 17), None, None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('8f6fc7ce-4de0-4b8b-973b-72fd70145b9c'), 'CSHL_004', 'M', datetime.date(2018, 11, 20), 'RR', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('90232fc5-5774-46a2-942a-44488084b4f6'), 'CSHL030', 'M', datetime.date(2019, 2, 19), 'LL', 'C57BL/6J', 'Jax', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 35)),
#        (UUID('91a23cb0-a72a-4850-a78a-7feabeb3cbe1'), 'CSK-IBL-001', 'M', datetime.date(2018, 12, 11), 'right', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('9253d979-544b-401c-93f8-5c5cd9793a11'), 'ZM_1898', 'U', datetime.date(2019, 6, 10), 'RB', None, None, 1, 'Blinded experiment.', datetime.datetime(2019, 9, 11, 4, 29, 18)),
#        (UUID('9268db69-a237-40c5-89bd-51932b52c5e3'), 'NYU-05', 'F', datetime.date(2019, 2, 26), '5', None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('92ce8b67-61a5-4591-a426-a4bb8bedc083'), 'ZM_343', 'F', datetime.date(2018, 8, 8), 'LF', 'Thy1-GCaMP6s', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 35)),
#        (UUID('9317beff-b3c3-42d2-8c3c-85b2f63b68f3'), 'CR_IBL2', 'F', datetime.date(2018, 10, 7), None, 'Sst-IRES-Cre', 'Cruciform BSU', 3, 'culled by HF', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('937bd78b-58d6-4987-8ecf-02450afb46f7'), 'ZM_1091', 'M', datetime.date(2018, 10, 23), None, 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 35)),
#        (UUID('9471b0ff-0027-4f06-94d8-0613e88f3878'), 'ZM_1371', 'M', datetime.date(2018, 12, 24), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('95241a9c-481b-443c-83a7-462165f729ec'), 'IBL-T3', 'F', datetime.date(2018, 11, 27), '3', None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('9540b01b-fa1e-4d1e-872b-0b4ccaae3888'), 'LEW010', 'F', datetime.date(2018, 5, 1), 'TL', 'tetO-G6s x CaMK-tTA', 'Cruciform BSU', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('96fef33b-3a98-4092-8bf9-df23d2df88c0'), 'ZM_1374', 'F', datetime.date(2018, 12, 31), 'RF', 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('986041a5-aea8-46a4-b8e8-5ede45317249'), '5856', 'M', datetime.date(2017, 12, 17), None, 'Dat-Cre', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 35)),
#        (UUID('98d5cbc2-cea7-4f62-93d5-2262c166bffa'), '6420', 'M', datetime.date(2018, 4, 4), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 35)),
#        (UUID('98fb4356-9847-49bf-941c-57b9e6a44e09'), 'ZM_1221', 'M', datetime.date(2019, 1, 4), 'LB', None, None, 1, 'Initially ordered to be trained in the IBL task, but user for different purposes.', datetime.datetime(2019, 9, 25, 1, 33, 35)),
#        (UUID('99758296-c09d-48e5-bbfd-dd372322c724'), 'ZM_205', 'M', datetime.date(2018, 7, 23), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 35)),
#        (UUID('99c07e09-7261-442d-b740-185b7d2086c5'), 'IBL_39', 'M', datetime.date(2018, 5, 24), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('9a354b77-26b9-4340-9eff-ca3f95b79c5d'), 'ZM_1736', 'F', datetime.date(2019, 2, 27), 'RF', 'C57BL/6J', 'CCU - Vivarium colonies', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('9a46fcfa-81cf-4742-87c0-bb95f90d5913'), 'KS015', 'M', datetime.date(2019, 6, 18), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('9b2cfcfe-8f57-44b0-b6e9-e1c7b9e6d8a2'), 'LTC02', 'F', datetime.date(2019, 3, 17), '1', None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('9b471b07-5903-4baa-b56d-368d385c850c'), 'DY_005', 'M', datetime.date(2019, 1, 1), 'none', 'C57BL/6J', 'Jax', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 35)),
#        (UUID('9c260018-589a-4881-ae19-508057acb3d2'), 'ZM_329', 'M', datetime.date(2018, 8, 7), 'RB', 'Vglut2-Cre', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 36)),
#        (UUID('9d625999-e9c0-4e65-887e-0c707db9ada5'), 'CSHL_016', 'M', datetime.date(2018, 12, 4), 'L', None, None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('9da5f0d1-56b3-47ee-9916-1805c836a651'), 'dop_5', 'F', datetime.date(2019, 3, 6), 'NA', 'Dat-Cre', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('9e0d3da6-3d18-4009-9785-3e2218646d00'), '6459', 'M', datetime.date(2018, 4, 14), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 36)),
#        (UUID('9e4cdc50-1d31-40c2-9e59-c39ee0cfce7f'), 'ibl_witten_01', 'M', datetime.date(2018, 5, 20), None, None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('9eb0fe50-9709-4a91-977c-37c8b51a0e48'), 'ZM_2101', 'U', datetime.date(2019, 6, 10), 'LF', None, None, 1, None, datetime.datetime(2019, 9, 11, 4, 29, 18)),
#        (UUID('9ffded1f-0ccb-45da-99e4-36eb242b7666'), 'example_CSHL1', 'U', None, None, None, 'Charles River', 1, 'example mouse, no real animal', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('a1ace543-c3a4-4895-8b17-f7ff8a1961d2'), 'lic_2', 'M', datetime.date(2018, 12, 28), 'NA', 'Dat-Cre', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('a316d5ff-94f8-42c7-884e-b2448cd40eee'), '5821', 'F', datetime.date(2017, 12, 10), None, 'ChR2', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 36)),
#        (UUID('a44a4d9d-c0ea-447e-801e-6215e05072ea'), 'SWC_023', 'M', datetime.date(2019, 6, 18), 'R (Front HP)', 'C57BL/6J', 'Charles River', 4, 'ID: 990763', datetime.datetime(2019, 9, 25, 1, 33, 36)),
#        (UUID('a4ec3fa0-5415-490a-bf2b-cbf07b017733'), 'KS001', 'M', datetime.date(2018, 10, 16), 'TL', 'TetO-GCaMP6s', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('a5b9ace4-b6cc-4b39-bf9b-c7c0e5d75560'), 'CSP001', 'M', datetime.date(2019, 2, 6), 'CSP1 on headbar', None, None, 1, None, datetime.datetime(2019, 8, 13, 17, 7, 33)),
#        (UUID('a676d86b-cff8-4dc9-93f0-65dbb27c85e2'), 'CSHL023', 'F', datetime.date(2019, 2, 19), 'LR', 'C57BL/6J', 'Jax', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 36)),
#        (UUID('a6e912a5-0acb-4543-98e5-a77093a24a7f'), 'ZM_1926', 'M', datetime.date(2019, 6, 20), 'LF', 'Sert-Cre', 'CCU - Margarida colonies', 1, 'Test effect of food switch on weight (Envigo 2014 > Picolab).', datetime.datetime(2019, 9, 10, 12, 30, 6)),
#        (UUID('a6f01d34-fad3-406b-9ca2-18e30e74d26c'), 'test_mouse0', 'M', datetime.date(2018, 11, 13), None, 'Ai148(TITL2-GCaMP6f)', 'Allen Institute', 1, None, datetime.datetime(2019, 8, 6, 20, 32, 56)),
#        (UUID('a73f0647-f566-4ded-98f8-7e4f6a18f37b'), 'IBL_38', 'M', datetime.date(2018, 5, 24), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
# ...
#        (UUID('c3707f6e-b963-4945-a4ab-8a9eb68ee778'), 'KS006', 'M', datetime.date(2018, 12, 10), None, 'C57BL/6J', None, 3, 'headbar implantation + 3d printed guide + UV cement', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('c387f80c-7a5c-4f11-a8e1-fe6ba3ed8cfe'), 'KS024', 'F', datetime.date(2019, 6, 25), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 9, 26, 4, 29, 35)),
#        (UUID('c4128347-33bc-4808-828b-c9ec8e92e77f'), 'ZM_1895', 'U', datetime.date(2019, 6, 10), 'LB', None, None, 1, 'Blinded experiment.', datetime.datetime(2019, 9, 11, 4, 29, 18)),
#        (UUID('c517bf82-483b-4066-a31d-d00c6d3f9637'), '5632', 'F', datetime.date(2017, 11, 8), None, 'Ntsr1-Cre', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 38)),
#        (UUID('c5ecfe21-ca1f-4024-b694-5ed53d2da11a'), 'IBL_42', 'M', datetime.date(2018, 5, 24), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('c600bc40-2f6f-449f-99be-562f6fbe331e'), 'ZM_210', 'F', datetime.date(2018, 7, 23), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 38)),
#        (UUID('c6843641-6492-4ba0-9116-ea7267dc61e9'), '4577', 'F', datetime.date(2017, 4, 11), None, 'Vglut2-ChR2', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 38)),
#        (UUID('c68cf5d5-e75a-46f1-8eda-a2db78cf4743'), 'ALK081', 'F', datetime.date(2018, 4, 13), 'ML', 'Pvalb-IRES-Cre', None, 3, 'perfused by HF', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('c6e8125f-b6c7-4349-b74d-32e8bd606f63'), 'KS023', 'F', datetime.date(2019, 6, 25), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 9, 26, 4, 29, 35)),
#        (UUID('c7760cc6-5c1a-40af-a8fd-f544b2de8b1a'), 'ZM_1218', 'M', datetime.date(2019, 1, 4), 'RF', None, None, 1, 'Initially ordered to be trained in the IBL task, but user for different purposes.', datetime.datetime(2019, 9, 25, 1, 33, 38)),
#        (UUID('c7a44209-9fe2-42ec-9fbf-13ecb3a0f8a3'), 'IBL_5', 'M', datetime.date(2018, 4, 2), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('c7a4c517-61b9-48ec-bfbe-30a8f419b5bb'), '437', 'M', datetime.date(2018, 6, 26), None, 'Sert-Cre', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 38)),
#        (UUID('c8b4e70d-3f13-42f6-ba22-ffb92c26beaf'), 'ibl_witten_04', 'M', datetime.date(2018, 11, 6), 'R', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 38)),
#        (UUID('c98f5521-fff1-4665-80b3-fb1f8dc6fcfc'), '6725', 'F', datetime.date(2018, 6, 3), None, 'Dat-Cre', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 38)),
#        (UUID('ca5899fb-69f7-4737-96bb-3f400e4a1590'), 'ZM_344', 'F', datetime.date(2018, 8, 8), 'RB', 'Thy1-GCaMP6s', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 39)),
#        (UUID('ca5b07c6-ecec-47be-9de6-4706c04d2ac9'), 'IBL_28', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('cb21532d-eb0f-4706-b088-bf4afc65e81a'), 'ZM_2107', 'U', datetime.date(2019, 6, 10), 'RF', None, None, 1, 'Blinded experiment.', datetime.datetime(2019, 9, 11, 4, 29, 18)),
#        (UUID('cb761037-e499-4ba4-a7b3-9be8b8410cbc'), 'ibl_witten_16', 'M', datetime.date(2019, 4, 23), 'NA', 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('cc9c6ddb-9d07-44c5-82d2-6587ec0c700c'), 'CSK-scan-004', 'M', datetime.date(2019, 6, 13), 'L', 'VGAT-ChR2', 'CSHL-Harris', 3, 'clear skull prep for inhibition scanning in IBL task', datetime.datetime(2019, 8, 29, 4, 24, 21)),
#        (UUID('ce22048c-79d2-4498-b385-67baea41258d'), 'CSH_ZAD_005', 'F', datetime.date(2019, 4, 16), 'LL', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('ceba369e-50e8-456f-b248-0f8091ebf2db'), 'Muller', 'F', datetime.date(2016, 9, 12), None, 'RCL-GCaMP6f x VGlut-Cre', 'Cruciform BSU', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('cff66dc1-765e-4e04-abef-92de05bf4f19'), 'IBL-T1', 'M', datetime.date(2018, 11, 27), '1', None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('d1413177-f435-4bc0-bcb1-af0f1a511b49'), 'SWC_003', 'F', datetime.date(2019, 1, 19), 'LR (Front HP)', 'C57BL/6J', 'Charles River', 4, 'ID: 919180', datetime.datetime(2019, 9, 25, 1, 33, 39)),
#        (UUID('d1c7418a-77c8-43d5-bfe3-2f91e858252d'), 'ibl_witten_12', 'F', datetime.date(2019, 3, 19), 'NA', 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('d1d274ed-56f5-40da-9a08-e6219d8a7b06'), 'ZM_2103', 'M', datetime.date(2019, 6, 13), 'striped tail', None, 'Jax', 3, None, datetime.datetime(2019, 8, 24, 4, 35, 14)),
#        (UUID('d29fc1f4-6015-4b97-91c5-7fc85304fbfb'), 'LTC04', 'F', datetime.date(2019, 2, 17), '1', None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('d43200a5-a79a-4aa3-922d-82a4e2c58c24'), 'IBL_31', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('d604ff7d-1b47-4861-9571-8c6ffdf9fedc'), 'CSHL033', 'M', datetime.date(2019, 4, 24), 'RL', 'C57BL/6J', 'CSHL - Woodbury', 3, None, datetime.datetime(2019, 9, 4, 4, 27, 55)),
#        (UUID('d7c0ac0f-2cc8-4b8a-ac40-bd9fcf50f095'), 'M181212_IC1', 'M', datetime.date(2018, 10, 9), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('d8189755-358c-4da0-bc8a-42d43cb1c850'), '5600', 'F', datetime.date(2017, 11, 9), None, 'Ntsr1-Cre', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 39)),
#        (UUID('d8eebe52-bfe1-466c-8094-4c805bafb823'), 'CtTa_0112_Breeding', 'U', None, None, None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('d9803440-511b-402b-ae4b-c3c0ec9e1955'), 'ibl_witten_08', 'F', datetime.date(2018, 11, 13), 'L', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 39)),
#        (UUID('d9fd8e6d-b6ba-4221-9edb-4a500749b444'), 'SWC_024', 'M', datetime.date(2019, 6, 18), 'L', None, None, 4, 'Front headplate', datetime.datetime(2019, 8, 21, 4, 19, 45)),
#        (UUID('da62bb12-f2f0-4e90-9d9a-413a8537b33b'), 'ZM_1372', 'F', datetime.date(2018, 12, 31), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('daada216-464d-4986-8e63-5ae2f470b3fd'), 'IBL_8', 'M', datetime.date(2018, 4, 2), None, None, 'Charles River', 1, 'Headplate came off today (2018-10-18), mouse was humanely ended', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('dcc7ffe6-b9af-43cf-bcd6-06ab741768c1'), 'CSK-IBL-003', 'M', datetime.date(2018, 12, 11), 'right left', 'C57BL/6J', 'Jax', 3, 'has alopecia from his cage mate', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('dcf2d0f5-08ff-4ceb-8adb-2eea94b90238'), 'IBL_22', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, 'Headbar came off in cage. Euthanized by Anne', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('dde97003-c4f7-4485-97f8-e989fce07ff4'), 'ibl_witten_13', 'U', datetime.date(2019, 4, 23), None, 'C57BL/6J', None, 1, None, datetime.datetime(2019, 8, 6, 20, 32, 56)),
#        (UUID('df2d615d-f8e1-41e5-bcab-480c8e4ba09f'), 'NYU-06', 'F', datetime.date(2019, 2, 26), None, None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('dfcbe240-32dc-427c-a8be-839e6ae3858f'), 'CSHL034', 'M', datetime.date(2019, 5, 24), 'RR', 'C57BL/6J', 'CSHL - Woodbury', 3, None, datetime.datetime(2019, 9, 4, 4, 27, 55)),
#        (UUID('e000c3d9-bc5b-4097-b68c-de8eb7e4d997'), '4573', 'M', datetime.date(2017, 4, 11), None, 'Vglut2-ChR2', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 40)),
#        (UUID('e0648c91-1b52-47be-9c74-be614af8ba76'), 'SWC_015', 'M', datetime.date(2019, 6, 4), 'L (Rear HP)', 'C57BL/6J', 'Charles River', 4, 'ID: 980127', datetime.datetime(2019, 9, 25, 1, 33, 40)),
#        (UUID('e0ad64a7-83a1-41ea-abff-738876bbaaca'), 'CSHL025', 'F', datetime.date(2019, 2, 19), 'LL', 'C57BL/6J', 'Jax', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 40)),
#        (UUID('e0b2075a-7a47-473c-9cdd-426dd20f6dfa'), 'CSH_ZAD_002', 'F', datetime.date(2019, 4, 16), 'L', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('e1ceadd7-e3c2-4fd9-98bc-148f17dd60c6'), 'ZM_1367', 'M', datetime.date(2018, 12, 24), 'RF', 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('e5482ccf-b521-425a-ac3f-710f58fb06a5'), 'IBL_005', 'F', datetime.date(2018, 12, 30), 'L', None, None, 4, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('e5918a15-c68f-43d7-87d8-43bc5a27ef6d'), 'CSK-scan-001', 'M', datetime.date(2019, 4, 9), 'LL', 'VGAT-ChR2', 'Jax', 3, 'VGat-ChR2 mouse with cleared skull preparation and headbar for scanning inactivation in IBL task', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('e68f8f75-0bb6-41e2-834c-5ddea4530382'), 'CSP006', 'M', datetime.date(2019, 7, 26), None, None, None, 1, None, datetime.datetime(2019, 9, 17, 4, 26, 52)),
#        (UUID('e7c33556-b7ba-4c56-9abc-9f2f6dfaa327'), 'ZM_1888', 'F', datetime.date(2019, 3, 4), None, 'C57BL/6J', None, 3, 'White tail.', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('e9cac4f8-effa-462a-8e41-323c58ef86dd'), 'KS002', 'M', datetime.date(2018, 10, 30), None, 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('ea214156-8b7f-48fe-a47a-85b49fad0e76'), 'CSH_ZAD_008', 'M', datetime.date(2019, 5, 6), 'RL', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('ea23741f-7dd7-41fa-adc1-2799111e178f'), 'ZM_1094', 'M', datetime.date(2018, 10, 23), 'RF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 40)),
#        (UUID('ea48c103-c1a0-460b-a679-4c4978b47ee6'), 'NYU-03', 'M', datetime.date(2018, 12, 18), '3', None, None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('eab67526-7d79-40ee-9179-60bdeec08613'), 'MW004', 'M', datetime.date(2018, 7, 17), 'TR', 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('eb834209-7724-40da-a9dd-85fdd928281c'), 'ZM_1925', 'U', datetime.date(2019, 6, 10), 'LF', None, None, 1, 'Blinded experiment.', datetime.datetime(2019, 9, 11, 4, 29, 18)),
#        (UUID('ecba4914-30c3-4a0b-9d65-1ef5d80ca5f2'), 'CSHL_001', 'M', datetime.date(2018, 11, 20), 'right ear', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('ecc301a5-4e89-4bb4-9ea0-dc02f10d2da0'), 'ZM_1748', 'M', datetime.date(2019, 2, 24), 'RF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('ed84fd6e-6378-4833-bbee-63449c07b0fd'), '_iblrig_test_mouse', 'U', datetime.date(2018, 11, 26), None, 'Ai148(TITL2-GCaMP6f)', 'Allen Institute', 1, None, datetime.datetime(2019, 8, 6, 20, 32, 56)),
#        (UUID('ee1a2b83-ab8d-4b71-8d23-04f7b21b1595'), 'NYU-04', 'M', datetime.date(2018, 12, 18), '4', None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('eee73e7a-a2eb-4949-91ae-a3d5a0375bd5'), 'IBL_19', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('efa5e878-6d7a-47ef-8ec8-ac7d6272cf22'), 'ZM_1150', 'F', datetime.date(2018, 12, 27), 'RFBLF', 'Tbet-GCaMP6f', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 40)),
#        (UUID('eff64787-e686-458a-a7b2-1c73eb0c495a'), 'CSH_ZAD_009', 'M', datetime.date(2019, 5, 6), 'RR', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('f01b97ab-0d2c-4825-b87f-b29f6daf3979'), 'NYU-07', 'F', datetime.date(2019, 2, 26), None, None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('f0af349e-b036-44a4-b8f1-c883c266ed52'), 'CSHL_013', 'F', datetime.date(2019, 2, 19), 'Right, Left', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 41)),
#        (UUID('f0b4123d-6ece-424b-8979-3d74bef641a0'), '5657', 'M', datetime.date(2017, 11, 10), None, 'VGAT-ChR2', 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 41)),
#        (UUID('f0edbf2f-f97d-490b-919c-1713afd6c2b3'), 'ZM_1738', 'M', datetime.date(2019, 2, 27), None, 'C57BL/6J', 'CCU - Vivarium colonies', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('f132e599-e6e9-4e7e-9f7d-15e045586c6f'), '6724', 'F', datetime.date(2018, 6, 3), None, 'Dat-Cre', 'CCU - Margarida colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 41)),
#        (UUID('f19b75f3-d3a5-4e87-b857-82d95f71213e'), 'ZM_1737', 'F', datetime.date(2019, 2, 27), 'LF', 'C57BL/6J', 'CCU - Vivarium colonies', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 41)),
#        (UUID('f2889c72-ce0c-465b-8af2-cfa8b4c9a8c4'), 'CSHL024', 'F', datetime.date(2019, 2, 19), 'RR', 'C57BL/6J', 'Jax', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 41)),
#        (UUID('f2cbdf1c-84bf-4752-98ef-de7029be3a24'), 'CSHL027', 'M', datetime.date(2019, 2, 19), 'L', 'C57BL/6J', None, 1, None, datetime.datetime(2019, 9, 25, 1, 33, 41)),
#        (UUID('f365dcc4-7523-4abd-9021-265f39b7290a'), 'ZM_1097', 'M', datetime.date(2018, 10, 23), 'LF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 41)),
#        (UUID('f3821028-b230-452d-886c-84aab766ca1e'), 'IBL_18', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('f3acdbcd-7c95-4dc8-b13e-8310048000c5'), 'DY_002', 'M', datetime.date(2019, 1, 1), 'none', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 41)),
#        (UUID('f43eaca5-cc3f-4bbf-bc64-01dbae31bd8f'), 'MW003', 'M', datetime.date(2018, 7, 17), 'none', 'C57BL/6J', None, 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('f498ba9d-d983-43fd-b8c1-b22ec919018e'), 'IBL-T2', 'F', datetime.date(2018, 11, 27), '2', None, None, 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('f7964cba-0846-4796-bcee-0b97d91b1326'), 'IBL_001', 'F', datetime.date(2019, 1, 9), 'R', None, None, 4, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('f8f2ec95-bc15-4c72-bf93-74185cbd049f'), 'ZM_338', 'M', datetime.date(2018, 8, 8), None, None, 'CCU - Margarida colonies', 1, None, datetime.datetime(2019, 9, 25, 1, 33, 41)),
#        (UUID('f953fa3b-d24f-4c47-9550-b11c2b9f96f2'), 'IBL_15', 'M', datetime.date(2018, 4, 23), None, None, 'Charles River', 1, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('faf159e2-1f4e-4477-8079-1a55fe5386a9'), 'LEW008', 'M', datetime.date(2018, 5, 1), 'TR', 'tetO-G6s x CaMK-tTA', 'Cruciform BSU', 3, 'MISSING END OF TAIL', datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('fb3c491d-233c-4ee0-abfa-5ea0222cd080'), 'ZM_1086', 'M', datetime.date(2018, 10, 23), 'RLF', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 41)),
#        (UUID('fb5e4b77-4057-4887-bf20-50f2459333eb'), 'CSHL_012', 'F', datetime.date(2019, 2, 19), 'Left', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 9, 25, 1, 33, 41)),
#        (UUID('fd493716-fc06-48a7-8f4f-fb82b6b072b5'), 'CSK-IBL-002', 'M', datetime.date(2018, 12, 11), 'left', 'C57BL/6J', 'Jax', 3, None, datetime.datetime(2019, 8, 6, 21, 30, 42)),
#        (UUID('fd943478-64bb-400c-9b19-5278e8de8bd7'), 'SWC_025', 'F', datetime.date(2019, 6, 18), 'none', None, None, 1, None, datetime.datetime(2019, 9, 16, 4, 26, 26)),
#        (UUID('ff1d0657-a5fa-4042-be77-b63758c8cb11'), 'CR_IBL1', 'F', datetime.date(2018, 10, 7), None, 'Sst-IRES-Cre', 'Cruciform BSU', 3, 'culled by HF', datetime.datetime(2019, 8, 6, 21, 30, 42))],
#       dtype=[('subject_uuid', 'O'), ('subject_nickname', 'O'), ('sex', 'O'), ('subject_birth_date', 'O'), ('ear_mark', 'O'), ('subject_line', 'O'), ('subject_source', 'O'), ('protocol_number', '<i8'), ('subject_description', 'O'), ('subject_ts', 'O')])
